# %% [markdown]
# In this notebook, we experimented with using a 1D Convolutional Neural Network (CNN) to classify behavioral windows as benign or ransomware. Our dataset consisted of feature vectors extracted from 0.1 second windows of activity, each treated as an independent sample. The initial CNN models were designed to be lightweight and efficient, but the first results were disappointing. The model struggled to generalize, often collapsing to trivial solutions such as predicting only one class.
#
# This led us to perform several experiments to identify what was limiting performance. We tested variations in depth, filter size, and regularization techniques. Specifically, we investigated the effects of Dropout and Batch Normalization. Surprisingly, removing both of these — which are typically beneficial in vision tasks — actually improved performance significantly. We also tested adding L2 regularization and using linear activations instead of ReLU, but neither of these proved useful. In fact, the simplest configuration turned out to be the most effective.
#
# The final model was built without Dropout, Batch Normalization, or L2 regularization. It used three Conv1D layers with kernel size 2, each followed by a ReLU activation. This was followed by a Global Average Pooling layer and two Dense layers before the sigmoid output. The model was trained with a batch size of 128 for up to 60 epochs, with early stopping applied to avoid overfitting.
#
# This configuration achieved the best results of all CNN variants tested. On the random split (where ransomware families were mixed between train and test sets), the model reached an accuracy of about 71% and an F1 score of 72%. On the much more difficult family-aware split, where entire ransomware families were held out of the training set, the model achieved about 66% accuracy and an F1 score of 71%. These are solid results for a simple CNN, especially considering the challenge of detecting unseen ransomware families.
#
# At the same time, the limitations of this approach became very clear. Although the model was able to learn patterns related to ransomware behavior, its performance was much better on the random split than on the family-aware split. This suggests that CNNs, which are designed to learn local feature patterns, are not ideally suited for this type of data. Behavioral features, unlike image pixels, do not have inherent spatial relationships. Additionally, ransomware behavior tends to unfold over time, and our CNN, working on isolated windows, had no way to capture this temporal dimension.
#
# Overall, this notebook served its purpose very well. It helped us push the CNN as far as it could reasonably go on this problem. We tested multiple architectural decisions, learned what worked and what didn’t, and reached the limits of what a simple CNN could achieve. For further progress and to better capture ransomware family generalization, our next steps will involve models that can learn temporal dependencies explicitly, such as LSTMs or Transformers. CNN will remain part of our toolbox for fast inference or when local pattern learning is sufficient, but moving forward, sequence-aware models are expected to take center stage.

# %% [markdown]
# # 1: Import libraries, Load dataset, Overview

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_parquet("../Datasets/final_prepared_dataset.parquet")

print("Dataset Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nClass Distribution:")
print(df['label'].value_counts())

print("\nUnique Families:")
print(df['family'].unique())
# Out:
# Dataset Shape: (194466, 26)
#
# Columns: ['family', 'window_id', 'read_throughput', 'read_lba_var', 'write_throughput', 'write_lba_var', 'write_entropy', 'mem_read_count_4k', 'mem_read_count_2m', 'mem_read_count_mmio', 'mem_read_gpa_var', 'mem_write_entropy', 'mem_write_count_4k', 'mem_write_count_2m', 'mem_write_count_mmio', 'mem_write_gpa_var', 'mem_readwrite_entropy', 'mem_readwrite_count_4k', 'mem_readwrite_count_2m', 'mem_readwrite_count_mmio', 'mem_readwrite_gpa_var', 'mem_exec_count_4k', 'mem_exec_count_2m', 'mem_exec_count_mmio', 'mem_exec_gpa_var', 'label']
#
# Class Distribution:
# label
# 0    101443
# 1     93023
# Name: count, dtype: int64
#
# Unique Families:
# ['AESCrypt' 'Conti' 'Darkside' 'Firefox' 'Idle' 'LockBit' 'Office' 'REvil'
#  'Ryuk' 'SDelete' 'WannaCry' 'Zip']

# %% [markdown]
# # 2: Define family-aware folds and create Train / Validation sets

# %%
family_aware_folds = {
    1: {
        "train_families": ['LockBit', 'WannaCry', 'Office', 'Zip', 'SDelete', 'AESCrypt'],
        "val_families": ['Firefox', 'Ryuk', 'Darkside']
    },
    2: {
        "train_families": ['Conti', 'Firefox', 'Idle', 'LockBit', 'REvil', 'Ryuk'],
        "val_families": ['Darkside', 'Office', 'Zip']
    },
    3: {
        "train_families": ['Darkside', 'Firefox', 'Office', 'REvil', 'Ryuk', 'Zip'],
        "val_families": ['Conti', 'LockBit', 'Idle']
    }
}

FOLD_NUMBER = 1

current_fold = family_aware_folds[FOLD_NUMBER]
train_families = current_fold["train_families"]
val_families = current_fold["val_families"]

test_families = ['Conti', 'Idle', 'AESCrypt']

print(f"Using Fold {FOLD_NUMBER}")
print("Train Families:", train_families)
print("Validation Families:", val_families)
print("Test Families:", test_families)
# Out:
# Using Fold 1
# Train Families: ['LockBit', 'WannaCry', 'Office', 'Zip', 'SDelete', 'AESCrypt']
# Validation Families: ['Firefox', 'Ryuk', 'Darkside']
# Test Families: ['Conti', 'Idle', 'AESCrypt']

# %%
SEQUENCE_LENGTH = 40

df_sorted = df.sort_values(["family", "window_id"]).reset_index(drop=True)
feature_cols = [c for c in df.columns if c not in ("family", "window_id", "label")]

sequences, labels, families = [], [], []

for fam, grp in df_sorted.groupby("family"):
    feats = grp[feature_cols].values          # shape (n_windows, 23)
    lbls  = grp["label"].values
    for i in range(len(grp) - SEQUENCE_LENGTH + 1):
        sequences.append(feats[i:i+SEQUENCE_LENGTH])
        labels.append(lbls[i + SEQUENCE_LENGTH - 1])   # label of last window
        families.append(fam)

sequences = np.asarray(sequences, dtype=np.float32)     # (N, 40, 23)
labels    = np.asarray(labels,    dtype=np.int64)
families  = np.asarray(families)

FOLD_NUMBER = 1          # or whichever you want to run
train_families = family_aware_folds[FOLD_NUMBER]["train_families"]
val_families   = family_aware_folds[FOLD_NUMBER]["val_families"]
test_families  = ['Conti', 'Idle', 'REvil']   # same hold-out set as before

train_mask = np.isin(families, train_families)
val_mask   = np.isin(families, val_families)
test_mask  = np.isin(families, test_families)

X_train, y_train = sequences[train_mask], labels[train_mask]
X_val,   y_val   = sequences[val_mask],   labels[val_mask]
X_test,  y_test  = sequences[test_mask],  labels[test_mask]

# random baseline (stratified, like before)
from sklearn.model_selection import train_test_split
X_rand_train, X_rand_test, y_rand_train, y_rand_test = train_test_split(
    sequences, labels, test_size=0.20, random_state=42, stratify=labels
)
X_rand_train, X_rand_val, y_rand_train, y_rand_val = train_test_split(
    X_rand_train, y_rand_train, test_size=0.10, random_state=42, stratify=y_rand_train
)

FEATURES        = sequences.shape[2]  # 23
flat_len        = SEQUENCE_LENGTH * FEATURES  # 920


def to_cnn(x):
    # x shape: (samples, 40, 23)
    return x.reshape(x.shape[0], flat_len, 1).astype(np.float32) # (samples, 920, 1)

X_train_cnn  = to_cnn(X_train)
X_val_cnn    = to_cnn(X_val)
X_test_cnn   = to_cnn(X_test)

X_train_rand_cnn = to_cnn(X_rand_train)
X_val_rand_cnn   = to_cnn(X_rand_val)
X_test_rand_cnn  = to_cnn(X_rand_test)

# %% [markdown]
# # 3: Prepare Random Split (70% Train, 15% Validation, 15% Test)

# %%
X_all = df.drop(columns=["family", "window_id", "label"]).values
y_all = df["label"].values

X_temp_random, X_test_random, y_temp_random, y_test_random = train_test_split(X_all, y_all, test_size=0.15, random_state=42, stratify=y_all)

X_train_random, X_val_random, y_train_random, y_val_random = train_test_split(X_temp_random, y_temp_random, test_size=0.176, random_state=42, stratify=y_temp_random)

print("Random Split Sizes:")
print("Train:", X_train_random.shape)
print("Validation:", X_val_random.shape)
print("Test:", X_test_random.shape)
# Out:
# Random Split Sizes:
# Train: (136203, 23)
# Validation: (29093, 23)
# Test: (29170, 23)

# %% [markdown]
# # 4: Reshape inputs for CNN (add channel dimension)

# %%
print("Family-Aware Split Shapes:")
print("X_train_cnn:", X_train_cnn.shape)
print("X_val_cnn:", X_val_cnn.shape)
print("X_test_cnn:", X_test_cnn.shape)

print("\nRandom Split Shapes:")
print("X_train_random_cnn:", X_train_random.shape)
print("X_val_random_cnn:", X_val_random.shape)
print("X_test_random_cnn:", X_test_random.shape)
# Out:
# Family-Aware Split Shapes:
# X_train_cnn: (100999, 920, 1)
# X_val_cnn: (47497, 920, 1)
# X_test_cnn: (45502, 920, 1)
#
# Random Split Shapes:
# X_train_random_cnn: (136203, 23)
# X_val_random_cnn: (29093, 23)
# X_test_random_cnn: (29170, 23)

# %% [markdown]
# # 5: Define CNN model architecture

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, GlobalAveragePooling1D, Dense, Dropout

def build_deeper_cnn_model(input_shape):
    model = Sequential()

    # First Conv1D Block
    model.add(Conv1D(filters=64, kernel_size=2, padding='same', input_shape=input_shape))
    #model.add(BatchNormalization())
    model.add(Activation('relu'))
    #model.add(Dropout(0.2))

    # Second Conv1D Block
    model.add(Conv1D(filters=128, kernel_size=2, padding='same'))
    #model.add(BatchNormalization())
    model.add(Activation('relu'))
    #model.add(Dropout(0.3))

    # Third Conv1D Block
    model.add(Conv1D(filters=256, kernel_size=2, padding='same'))
    #model.add(BatchNormalization())
    model.add(Activation('relu'))
    #model.add(Dropout(0.4))

    # Global Average Pooling
    model.add(GlobalAveragePooling1D())

    # Fully connected layers
    model.add(Dense(256, activation='relu'))
    #model.add(Dropout(0.3))

    model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    return model

input_shape = input_shape = (flat_len, 1)  
cnn_model = build_deeper_cnn_model(input_shape)

cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 920, 64)        │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 920, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 920, 128)       │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 920, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 920, 256)       │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 920, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 164,801 (643.75 KB)
#  Trainable params: 164,801 (643.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 6: Compile the CNN model

# %%
cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 7: Train CNN on Family-Aware Split

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

history = cnn_model.fit(
    X_train_cnn, y_train,
    validation_data=(X_val_cnn, y_val),
    epochs=60,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 386s 488ms/step - accuracy: 0.5884 - loss: 3365138283364352.0000 - val_accuracy: 0.3934 - val_loss: 1.8667 - learning_rate: 0.0010
# Epoch 2/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 409s 518ms/step - accuracy: 0.6948 - loss: 83486892032.0000 - val_accuracy: 0.5146 - val_loss: 2.0791 - learning_rate: 0.0010
# Epoch 3/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 399s 506ms/step - accuracy: 0.7914 - loss: 9023350784.0000 - val_accuracy: 0.5048 - val_loss: 3.5520 - learning_rate: 0.0010
# Epoch 4/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 353s 447ms/step - accuracy: 0.8004 - loss: 0.6873 - val_accuracy: 0.5657 - val_loss: 2.9373 - learning_rate: 0.0010
# Epoch 5/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 324s 410ms/step - accuracy: 0.8290 - loss: 0.4344 - val_accuracy: 0.5859 - val_loss: 2.5254 - learning_rate: 5.0000e-04
# Epoch 6/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 409s 518ms/step - accuracy: 0.8318 - loss: 0.4050 - val_accuracy: 0.6002 - val_loss: 2.5211 - learning_rate: 5.0000e-04
# Epoch 7/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 416s 527ms/step - accuracy: 0.8320 - loss: 1619545600.0000 - val_accuracy: 0.5805 - val_loss: 2.6372 - learning_rate: 5.0000e-04
# Epoch 8/60
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 414s 524ms/step - accuracy: 0.8227 - loss: 0.4800 - val_accuracy: 0.5915 - val_loss: 2.5500 - learning_rate: 2.5000e-04

# %% [markdown]
# # 8: Plot Loss and Accuracy over time

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(epochs, loss, 'b-', label='Training Loss')
axs[0].plot(epochs, val_loss, 'r-', label='Validation Loss')
axs[0].set_title('Loss over Epochs')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(epochs, acc, 'b-', label='Training Accuracy')
axs[1].plot(epochs, val_acc, 'r-', label='Validation Accuracy')
axs[1].set_title('Accuracy over Epochs')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9: Evaluate CNN on Validation (Family-Aware Split)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

y_val_pred_proba = cnn_model.predict(X_val_cnn).ravel()
y_val_pred = (y_val_pred_proba >= 0.5).astype(int)

val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred)
val_recall = recall_score(y_val, y_val_pred)
val_f1 = f1_score(y_val, y_val_pred)

print("Validation Metrics (Family-Aware Split):")
print(f"Accuracy : {val_accuracy:.4f}")
print(f"Precision: {val_precision:.4f}")
print(f"Recall   : {val_recall:.4f}")
print(f"F1 Score : {val_f1:.4f}")

cm = confusion_matrix(y_val, y_val_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Ransomware'], yticklabels=['Benign', 'Ransomware'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Validation - Family Aware Split)")
plt.show()
# Out:
#  292/1485 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step

# %% [markdown]
#  ##   Validation accuracy is stuck at 0.562 → this is actually VERY informative.
#
# It tells us that the CNN cannot find good decision boundaries for unseen families → it is collapsing to "predict everything ransomware", because in unseen families → ransomware is dominant (or ambiguous), so safest way for CNN (without advanced regularization or meta-learning) is to overpredict positive → 100% recall but poor precision → exactly like we saw.
#
# This is 100% aligned with our lightweight models observations → even XGBoost was weak in family-aware unseen generalization → only about ~50% accuracy.

# %% [markdown]
# # 10: Train CNN on Random Split

# %%
cnn_model_random = build_deeper_cnn_model((X_train_random_cnn.shape[1], X_train_random_cnn.shape[2]))

cnn_model_random.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

history_random = cnn_model_random.fit(
    X_train_random_cnn, y_train_random,
    validation_data=(X_val_random_cnn, y_val_random),
    epochs=60,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)
# Out:
# Epoch 1/60
# /home/exmachina/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1065/1065 - 13s - 12ms/step - accuracy: 0.5349 - loss: 5396660767162368.0000 - val_accuracy: 0.5987 - val_loss: 2.1828 - learning_rate: 1.0000e-03
# Epoch 2/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.6150 - loss: 1243526912.0000 - val_accuracy: 0.6426 - val_loss: 1.1973 - learning_rate: 1.0000e-03
# Epoch 3/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.6454 - loss: 1.3800 - val_accuracy: 0.6673 - val_loss: 1.1788 - learning_rate: 1.0000e-03
# Epoch 4/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6717 - loss: 1.2332 - val_accuracy: 0.6774 - val_loss: 1.0363 - learning_rate: 1.0000e-03
# Epoch 5/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6820 - loss: 1.2524 - val_accuracy: 0.6867 - val_loss: 1.0549 - learning_rate: 1.0000e-03
# Epoch 6/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.6847 - loss: 1.1331 - val_accuracy: 0.6879 - val_loss: 0.9226 - learning_rate: 1.0000e-03
# Epoch 7/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6906 - loss: 1.0146 - val_accuracy: 0.6863 - val_loss: 1.5153 - learning_rate: 1.0000e-03
# Epoch 8/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6963 - loss: 1.0498 - val_accuracy: 0.6990 - val_loss: 1.1534 - learning_rate: 1.0000e-03
# Epoch 9/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6997 - loss: 1.0988 - val_accuracy: 0.7012 - val_loss: 0.9571 - learning_rate: 1.0000e-03
# Epoch 10/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.7017 - loss: 0.8490 - val_accuracy: 0.7050 - val_loss: 0.7209 - learning_rate: 5.0000e-04
# Epoch 11/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7031 - loss: 0.8499 - val_accuracy: 0.7092 - val_loss: 0.9048 - learning_rate: 5.0000e-04
# Epoch 12/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.7040 - loss: 0.8113 - val_accuracy: 0.7071 - val_loss: 0.8225 - learning_rate: 5.0000e-04
# Epoch 13/60
# 1065/1065 - 13s - 12ms/step - accuracy: 0.7041 - loss: 0.7852 - val_accuracy: 0.7083 - val_loss: 0.6701 - learning_rate: 5.0000e-04
# Epoch 14/60
# 1065/1065 - 12s - 12ms/step - accuracy: 0.6939 - loss: 476657647616.0000 - val_accuracy: 0.6286 - val_loss: 4.9282 - learning_rate: 5.0000e-04
# Epoch 15/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.6999 - loss: 1.3290 - val_accuracy: 0.7080 - val_loss: 0.8647 - learning_rate: 5.0000e-04
# Epoch 16/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7053 - loss: 0.8718 - val_accuracy: 0.7098 - val_loss: 0.7617 - learning_rate: 5.0000e-04
# Epoch 17/60
# 1065/1065 - 12s - 11ms/step - accuracy: 0.7059 - loss: 0.7608 - val_accuracy: 0.7090 - val_loss: 0.7164 - learning_rate: 2.5000e-04
# Epoch 18/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7055 - loss: 0.7158 - val_accuracy: 0.7081 - val_loss: 0.6800 - learning_rate: 2.5000e-04
# Epoch 19/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7052 - loss: 0.6945 - val_accuracy: 0.7096 - val_loss: 0.6876 - learning_rate: 2.5000e-04
# Epoch 20/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7061 - loss: 0.6574 - val_accuracy: 0.7090 - val_loss: 0.6502 - learning_rate: 1.2500e-04
# Epoch 21/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7060 - loss: 0.6377 - val_accuracy: 0.7086 - val_loss: 0.6584 - learning_rate: 1.2500e-04
# Epoch 22/60
# 1065/1065 - 11s - 11ms/step - accuracy: 0.7064 - loss: 0.6345 - val_accuracy: 0.7100 - val_loss: 0.6296 - learning_rate: 1.2500e-04
# Epoch 23/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7069 - loss: 0.6229 - val_accuracy: 0.7100 - val_loss: 0.6342 - learning_rate: 1.2500e-04
# Epoch 24/60
# 1065/1065 - 33s - 31ms/step - accuracy: 0.7071 - loss: 0.6183 - val_accuracy: 0.7088 - val_loss: 0.6282 - learning_rate: 1.2500e-04
# Epoch 25/60
# 1065/1065 - 33s - 31ms/step - accuracy: 0.7076 - loss: 0.6140 - val_accuracy: 0.7094 - val_loss: 0.6787 - learning_rate: 1.2500e-04
# Epoch 26/60
# 1065/1065 - 31s - 29ms/step - accuracy: 0.7076 - loss: 0.6218 - val_accuracy: 0.7114 - val_loss: 0.6156 - learning_rate: 1.2500e-04
# Epoch 27/60
# 1065/1065 - 33s - 31ms/step - accuracy: 0.7075 - loss: 0.6024 - val_accuracy: 0.7103 - val_loss: 0.6658 - learning_rate: 1.2500e-04
# Epoch 28/60
# 1065/1065 - 30s - 28ms/step - accuracy: 0.7076 - loss: 0.6082 - val_accuracy: 0.7113 - val_loss: 0.6126 - learning_rate: 1.2500e-04
# Epoch 29/60
# 1065/1065 - 31s - 29ms/step - accuracy: 0.7074 - loss: 0.6150 - val_accuracy: 0.7100 - val_loss: 0.6744 - learning_rate: 1.2500e-04
# Epoch 30/60
# 1065/1065 - 31s - 29ms/step - accuracy: 0.7079 - loss: 0.6010 - val_accuracy: 0.7111 - val_loss: 0.6146 - learning_rate: 1.2500e-04
# Epoch 31/60
# 1065/1065 - 31s - 29ms/step - accuracy: 0.7079 - loss: 0.6038 - val_accuracy: 0.7107 - val_loss: 0.6253 - learning_rate: 1.2500e-04
# Epoch 32/60
# 1065/1065 - 29s - 27ms/step - accuracy: 0.7086 - loss: 0.5864 - val_accuracy: 0.7109 - val_loss: 0.6165 - learning_rate: 6.2500e-05
# Epoch 33/60
# 1065/1065 - 29s - 28ms/step - accuracy: 0.7082 - loss: 0.5891 - val_accuracy: 0.7109 - val_loss: 0.6186 - learning_rate: 6.2500e-05
# Epoch 34/60
# 1065/1065 - 30s - 28ms/step - accuracy: 0.7083 - loss: 0.5865 - val_accuracy: 0.7108 - val_loss: 0.6051 - learning_rate: 6.2500e-05
# Epoch 35/60
# 1065/1065 - 29s - 27ms/step - accuracy: 0.7082 - loss: 0.5850 - val_accuracy: 0.7113 - val_loss: 0.6016 - learning_rate: 6.2500e-05
# Epoch 36/60
# 1065/1065 - 29s - 27ms/step - accuracy: 0.7086 - loss: 0.5858 - val_accuracy: 0.7112 - val_loss: 0.6064 - learning_rate: 6.2500e-05
# Epoch 37/60
# 1065/1065 - 29s - 28ms/step - accuracy: 0.7088 - loss: 0.5810 - val_accuracy: 0.7114 - val_loss: 0.6033 - learning_rate: 6.2500e-05
# Epoch 38/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7086 - loss: 0.5832 - val_accuracy: 0.7115 - val_loss: 0.5974 - learning_rate: 6.2500e-05
# Epoch 39/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7087 - loss: 0.5940 - val_accuracy: 0.7117 - val_loss: 0.5968 - learning_rate: 6.2500e-05
# Epoch 40/60
# 1065/1065 - 29s - 27ms/step - accuracy: 0.7085 - loss: 0.5907 - val_accuracy: 0.7111 - val_loss: 0.5935 - learning_rate: 6.2500e-05
# Epoch 41/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7086 - loss: 0.5847 - val_accuracy: 0.7112 - val_loss: 0.6057 - learning_rate: 6.2500e-05
# Epoch 42/60
# 1065/1065 - 24s - 23ms/step - accuracy: 0.7086 - loss: 0.5822 - val_accuracy: 0.7114 - val_loss: 0.6022 - learning_rate: 6.2500e-05
# Epoch 43/60
# 1065/1065 - 21s - 20ms/step - accuracy: 0.7090 - loss: 0.5842 - val_accuracy: 0.7115 - val_loss: 0.6239 - learning_rate: 6.2500e-05
# Epoch 44/60
# 1065/1065 - 22s - 21ms/step - accuracy: 0.7091 - loss: 0.5778 - val_accuracy: 0.7118 - val_loss: 0.5989 - learning_rate: 3.1250e-05
# Epoch 45/60
# 1065/1065 - 21s - 20ms/step - accuracy: 0.7094 - loss: 0.5721 - val_accuracy: 0.7114 - val_loss: 0.5951 - learning_rate: 3.1250e-05
# Epoch 46/60
# 1065/1065 - 22s - 21ms/step - accuracy: 0.7092 - loss: 0.5736 - val_accuracy: 0.7111 - val_loss: 0.5941 - learning_rate: 3.1250e-05
# Epoch 47/60
# 1065/1065 - 23s - 22ms/step - accuracy: 0.7096 - loss: 0.5670 - val_accuracy: 0.7118 - val_loss: 0.5911 - learning_rate: 1.5625e-05
# Epoch 48/60
# 1065/1065 - 23s - 22ms/step - accuracy: 0.7095 - loss: 0.5688 - val_accuracy: 0.7115 - val_loss: 0.5870 - learning_rate: 1.5625e-05
# Epoch 49/60
# 1065/1065 - 22s - 20ms/step - accuracy: 0.7095 - loss: 0.5676 - val_accuracy: 0.7119 - val_loss: 0.5881 - learning_rate: 1.5625e-05
# Epoch 50/60
# 1065/1065 - 21s - 20ms/step - accuracy: 0.7097 - loss: 0.5663 - val_accuracy: 0.7116 - val_loss: 0.5900 - learning_rate: 1.5625e-05
# Epoch 51/60
# 1065/1065 - 22s - 21ms/step - accuracy: 0.7093 - loss: 0.5712 - val_accuracy: 0.7116 - val_loss: 0.5869 - learning_rate: 1.5625e-05
# Epoch 52/60
# 1065/1065 - 24s - 22ms/step - accuracy: 0.7096 - loss: 0.5684 - val_accuracy: 0.7117 - val_loss: 0.5812 - learning_rate: 1.5625e-05
# Epoch 53/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7099 - loss: 0.5671 - val_accuracy: 0.7112 - val_loss: 0.5900 - learning_rate: 1.5625e-05
# Epoch 54/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7096 - loss: 0.5684 - val_accuracy: 0.7123 - val_loss: 0.5799 - learning_rate: 1.5625e-05
# Epoch 55/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7097 - loss: 0.5686 - val_accuracy: 0.7118 - val_loss: 0.5771 - learning_rate: 1.5625e-05
# Epoch 56/60
# 1065/1065 - 26s - 25ms/step - accuracy: 0.7096 - loss: 0.5704 - val_accuracy: 0.7116 - val_loss: 0.5870 - learning_rate: 1.5625e-05
# Epoch 57/60
# 1065/1065 - 28s - 26ms/step - accuracy: 0.7096 - loss: 0.5743 - val_accuracy: 0.7120 - val_loss: 0.5810 - learning_rate: 1.5625e-05
# Epoch 58/60
# 1065/1065 - 27s - 26ms/step - accuracy: 0.7094 - loss: 0.5726 - val_accuracy: 0.7115 - val_loss: 0.5854 - learning_rate: 1.5625e-05
# Epoch 59/60
# 1065/1065 - 22s - 21ms/step - accuracy: 0.7097 - loss: 0.5675 - val_accuracy: 0.7121 - val_loss: 0.5771 - learning_rate: 7.8125e-06
# Epoch 60/60
# 1065/1065 - 22s - 21ms/step - accuracy: 0.7094 - loss: 0.5664 - val_accuracy: 0.7113 - val_loss: 0.5823 - learning_rate: 7.8125e-06

# %% [markdown]
# # 11: Plot Loss and Accuracy over time (Random Split)

# %%
acc = history_random.history['accuracy']
val_acc = history_random.history['val_accuracy']
loss = history_random.history['loss']
val_loss = history_random.history['val_loss']

epochs = range(1, len(acc) + 1)

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(epochs, loss, 'b-', label='Training Loss')
axs[0].plot(epochs, val_loss, 'r-', label='Validation Loss')
axs[0].set_title('Loss over Epochs (Random Split)')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(epochs, acc, 'b-', label='Training Accuracy')
axs[1].plot(epochs, val_acc, 'r-', label='Validation Accuracy')
axs[1].set_title('Accuracy over Epochs (Random Split)')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 12: Evaluate CNN on Random Split (Test Set)

# %%
y_test_random_pred_proba = cnn_model_random.predict(X_test_random_cnn).ravel()
y_test_random_pred = (y_test_random_pred_proba >= 0.5).astype(int)

test_accuracy = accuracy_score(y_test_random, y_test_random_pred)
test_precision = precision_score(y_test_random, y_test_random_pred)
test_recall = recall_score(y_test_random, y_test_random_pred)
test_f1 = f1_score(y_test_random, y_test_random_pred)

print("Test Metrics (Random Split):")
print(f"Accuracy : {test_accuracy:.4f}")
print(f"Precision: {test_precision:.4f}")
print(f"Recall   : {test_recall:.4f}")
print(f"F1 Score : {test_f1:.4f}")

cm_random = confusion_matrix(y_test_random, y_test_random_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm_random, annot=True, fmt='d', cmap='Greens', xticklabels=['Benign', 'Ransomware'], yticklabels=['Benign', 'Ransomware'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Test - Random Split)")
plt.show()
# Out:
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Test Metrics (Random Split):
# Accuracy : 0.7108
# Precision: 0.6698
# Recall   : 0.7798
# F1 Score : 0.7206

# %% [markdown]
# In this notebook, we experimented with using a 1D Convolutional Neural Network (CNN) to classify behavioral windows as benign or ransomware. Our dataset consisted of feature vectors extracted from 0.1 second windows of activity, each treated as an independent sample. The initial CNN models were designed to be lightweight and efficient, but the first results were disappointing. The model struggled to generalize, often collapsing to trivial solutions such as predicting only one class.
#
# This led us to perform several experiments to identify what was limiting performance. We tested variations in depth, filter size, and regularization techniques. Specifically, we investigated the effects of Dropout and Batch Normalization. Surprisingly, removing both of these — which are typically beneficial in vision tasks — actually improved performance significantly. We also tested adding L2 regularization and using linear activations instead of ReLU, but neither of these proved useful. In fact, the simplest configuration turned out to be the most effective.
#
# The final model was built without Dropout, Batch Normalization, or L2 regularization. It used three Conv1D layers with kernel size 2, each followed by a ReLU activation. This was followed by a Global Average Pooling layer and two Dense layers before the sigmoid output. The model was trained with a batch size of 128 for up to 60 epochs, with early stopping applied to avoid overfitting.
#
# This configuration achieved the best results of all CNN variants tested. On the random split (where ransomware families were mixed between train and test sets), the model reached an accuracy of about 71% and an F1 score of 72%. On the much more difficult family-aware split, where entire ransomware families were held out of the training set, the model achieved about 66% accuracy and an F1 score of 71%. These are solid results for a simple CNN, especially considering the challenge of detecting unseen ransomware families.
#
# At the same time, the limitations of this approach became very clear. Although the model was able to learn patterns related to ransomware behavior, its performance was much better on the random split than on the family-aware split. This suggests that CNNs, which are designed to learn local feature patterns, are not ideally suited for this type of data. Behavioral features, unlike image pixels, do not have inherent spatial relationships. Additionally, ransomware behavior tends to unfold over time, and our CNN, working on isolated windows, had no way to capture this temporal dimension.
#
# Overall, this notebook served its purpose very well. It helped us push the CNN as far as it could reasonably go on this problem. We tested multiple architectural decisions, learned what worked and what didn’t, and reached the limits of what a simple CNN could achieve. For further progress and to better capture ransomware family generalization, our next steps will involve models that can learn temporal dependencies explicitly, such as LSTMs or Transformers. CNN will remain part of our toolbox for fast inference or when local pattern learning is sufficient, but moving forward, sequence-aware models are expected to take center stage.
